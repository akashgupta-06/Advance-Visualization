# %% [markdown]
# # Movie Rating Project

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\USER\Downloads\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.shape
# Out:
# (559, 6)

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.2

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns  # make atribute clean as bussins
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings','BudgetMillion', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.describe()
# if you look at the year the data type is int but when you look at the mean value it showing 2009 which is meaningless
# we have to change to categroy type 
# also from object datatype we will convert to category datatypes
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.describe()    # now we get int value mean and year gone
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories    # get categories using cat
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRatings')
plt.show()
# Audience rating is more dominant then critics rating

# %%
# kind : ["scatter" | "kde" | "hist" | "hex" | "reg" | "resid" ]
# Draw a plot of two variables with bivariate and univariate graphs.called jointplot
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='hex')
plt.show()

# %%
m1 = sns.distplot(movies.AudienceRatings)
plt.show()
# y-axis generated by sns automatically

# %%
m1 = sns.displot(movies.CriticRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.displot(movies.CriticRating, bins = 15)
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = sns.displot(movies.CriticRating, bins=15)
plt.show()

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x = 'CriticRating', y = 'AudienceRatings', fit_reg=True)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x = 'CriticRating', y = 'AudienceRatings', fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x = 'CriticRating', y = 'AudienceRatings', 
                  fit_reg=True, hue = 'Genre')
plt.show()

# %%
# subplot
ax = plt.subplot(1,2,1)
ax = plt.subplot(1,2,2)
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies[movies.Genre == 'Action'].BudgetMillion, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins = 20)
plt.legend()
plt.show()

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
# Box plot
w = sns.boxplot(data=movies, x='Genre', y= 'CriticRating')
plt.show()

# %%
# violinplot
w = sns.violinplot(data=movies, x='Genre', y= 'CriticRating')
plt.show()

# %%
w = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y= 'AudienceRatings')
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %% [markdown]
# ## multivariate analysis using heatmap,pairplot and facetgrid

# %%
g = sns.FacetGrid(movies, row = 'Genre', col='Year', hue = 'Genre')
plt.show()       # Multi-plot grid for plotting (7 genre * 5 year)==35

# %%
plt.scatter(movies.CriticRating,movies.AudienceRatings)
plt.show()     # fill it to above graph

# %%
g = sns.FacetGrid(movies, row = 'Genre', col='Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating',	'AudienceRatings')
plt.show()

# %%
# you can populated any type of chat. 

g =sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion') 
plt.show()

# %%
k1 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRatings)
plt.show()
# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(x= movies.CriticRating,y =movies.AudienceRatings,
                 shade = True,shade_lowest=True,cmap='Reds')
plt.show()

# %%
k1 = sns.kdeplot(x= movies.CriticRating,y =movies.AudienceRatings,
                 shade = True,shade_lowest=False,cmap='Reds')
plt.show()

# %%
k1 = sns.kdeplot(x= movies.CriticRating,y =movies.AudienceRatings,
                 shade = True,shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x = movies.BudgetMillion, y=movies.AudienceRatings,
                 shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(x=movies.BudgetMillion, y=movies.AudienceRatings,ax=axes[0])
k2 = sns.kdeplot(x=movies.BudgetMillion, y=movies.CriticRating,ax = axes[1])
plt.show()

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (10,10))

k1 = sns.kdeplot(x=movies.BudgetMillion, y=movies.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillion, y=movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x=movies.CriticRating, y= movies.AudienceRatings,cmap='Reds',ax = axes[1,1])

plt.tight_layout()
plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x=movies.BudgetMillion,y=movies.AudienceRatings, \
                 fill=True , shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x=movies.BudgetMillion, y=movies.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x=movies.BudgetMillion,y=movies.CriticRating,\
                 fill=True , shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillion,y=movies.CriticRating,\
                  cmap= 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRatings, \
                 fill=True ,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(x=movies.CriticRating,y= movies.AudienceRatings, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %%
done
